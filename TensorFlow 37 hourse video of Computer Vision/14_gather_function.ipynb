# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Using the function gather

# %%
params=tf.constant([[1, 4, 3, 1, 3],
                   [6, 2, 5, 4, 5 ],
                   [0, 3, 3, 4, 6 ],
                   [1, 5, 5, 2, 5 ]],dtype=tf.float32)
params
#number of dimensions
print("Number of dimensions",params.shape)
#number of elements
print("Number of elements",tf.size(params))
# Out:
# Number of dimensions (4, 5)
# Number of elements tf.Tensor(20, shape=(), dtype=int32)

# %% [markdown]
# Use the gather function

# %%
tf.gather(params,[2,1],axis=0)
# Out:
# <tf.Tensor: shape=(2, 5), dtype=float32, numpy=
# array([[0., 3., 3., 4., 6.],
#        [6., 2., 5., 4., 5.]], dtype=float32)>

# %%
tf.gather(params,[0,1],axis=1)
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[1., 4.],
#        [6., 2.],
#        [0., 3.],
#        [1., 5.]], dtype=float32)>

# %% [markdown]
# THE function of gather_nd

# %%
print(params)
indices=[[0,1],[1,2]]

tf.gather_nd(params,indices)
# Out:
# tf.Tensor(
# [[1. 4. 3. 1. 3.]
#  [6. 2. 5. 4. 5.]
#  [0. 3. 3. 4. 6.]
#  [1. 5. 5. 2. 5.]], shape=(4, 5), dtype=float32)
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([4., 5.], dtype=float32)>

# %%
params=tf.constant([[1, 4, 3, 1, 3],
                   [6, 2, 5, 4, 5 ],
                   [0, 3, 3, 4, 6 ],
                   [1, 5, 5, 2, 5 ]],dtype=tf.float32)
params
#number of dimensions
print("Number of dimensions",params.shape)
#number of elements
print("Number of elements",tf.size(params))
# Out:
# Number of dimensions (4, 5)
# Number of elements tf.Tensor(20, shape=(), dtype=int32)

# %%
import tensorflow as tf
import numpy as np

# Create a sample dataset
data = np.random.randn(10000, 20)  # 10,000 samples with 20 features each
labels = np.random.randint(2, size=(10000, 1))  # Binary labels for the samples

# Define a simple Sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Use a batch size of 100
batch_size = 100
epochs = 10

# Train the model
model.fit(data, labels, batch_size=batch_size, epochs=epochs)
# Out:
# C:\Users\Muhammad Ihtesham\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5073 - loss: 0.7107
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5121 - loss: 0.6956
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5294 - loss: 0.6926
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5268 - loss: 0.6908
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5387 - loss: 0.6887
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5449 - loss: 0.6869
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5504 - loss: 0.6864
# ...

# %%
import tensorflow as tf
import numpy as np

# Create a sample dataset
data = np.random.randn(1000000, 20)  # 1,000 samples with 20 features each
labels = np.random.randint(2, size=(1000000, 1))  # Binary labels for the samples

# Define a simple Sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid'),
    tf.keras.layers.Dense(32, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid'),
    tf.keras.layers.Dense(64, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid'),
    tf.keras.layers.Dense(128, activation='relu', input_shape=(20,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Use a batch size of 100 and train for 5 epochs
batch_size = 500
epochs = 20

# Train the model
history = model.fit(data, labels, batch_size=batch_size, epochs=epochs)
# Out:
# Epoch 1/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5001 - loss: 0.6932
# Epoch 2/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4997 - loss: 0.6932
# Epoch 3/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5005 - loss: 0.6932
# Epoch 4/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.4984 - loss: 0.6932
# Epoch 5/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.4990 - loss: 0.6932
# Epoch 6/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.4994 - loss: 0.6932
# Epoch 7/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.4994 - loss: 0.6932
# Epoch 8/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.4994 - loss: 0.6932
# Epoch 9/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5011 - loss: 0.6931
# Epoch 10/20
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.4997 - loss: 0.6932
# Epoch 11/20
# ...

# %%
import matplotlib.pyplot as plt

# Plot the training loss and accuracy over epochs
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
